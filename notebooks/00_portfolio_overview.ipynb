# %% [markdown]
# # Biohub · An evidence-led cell-tracking research portfolio
#
# **Alvaro Mendizabal** · 3D detection, sparse-supervision tracking, representation engineering, and error-driven experiments.
#
# This overview is executed from committed evidence. The figures are genuine Plotly outputs extracted from completed AWS notebooks; they are not regenerated experiment results. The complete numbered notebooks preserve the original analyses.
#
# **The portfolio snapshot is complete as documentation; the competitive research goal is not.**

# %%
from pathlib import Path
import json
from IPython.display import Image, display
ROOT=Path.cwd()
if not (ROOT/'reports').is_dir(): ROOT=ROOT.parent
summary=json.loads((ROOT/'reports/portfolio_summary.json').read_text())
score=json.loads((ROOT/'reports/official_submission.json').read_text())
assert score['status']=='scored' and score['official_public_score']==summary['official_public_score']
print('Official public score:',score['official_public_score'])
print('Submission:',score['submission_ref'],'— saved notebook version',score['kernel_version'])
print('Captured public leader:',summary['leader_snapshot_score'])
print('Recorded comparable gap:',round(summary['leader_snapshot_score']-score['official_public_score'],6))
print('This is a dated leaderboard snapshot, not a live rank.')
# Out:
# Official public score: 0.947
# Submission: 56376695 — saved notebook version 1
# Captured public leader: 0.974
# Recorded comparable gap: 0.027
# This is a dated leaderboard snapshot, not a live rank.

# %% [markdown]
# ## 1 · Preserve the strong reference, test additions fairly
#
# The 0.947 score is credited to a faithful public Harmonic Fusion inference reproduction using external pretrained weights. Original feature and graph research was then evaluated against frozen inputs. The five-video comparison below is **local**, on two previously inspected embryos, not a prediction of the official leaderboard.
#
# The tested temporal-exchange rule made no accepted changes; its negative result prevented an unsupported promotion.

# %%
display(Image(filename=str(ROOT/'assets/temporal_reassignment_0.png')))
print('Source: completed AWS Notebook 27; no experiment was rerun for this overview.')
# Out:
# Source: completed AWS Notebook 27; no experiment was rerun for this overview.

# %% [markdown]
# ## 2 · Let exact error attribution determine the next hypothesis
#
# The same saved baseline contained 111 incorrect and 112 missed edges. The sparse-label metric distinguishes unannotated predictions from measurable errors. The audit below separated mismatched endpoints and competing assignments instead of labeling every unmatched cell as a false positive.
#
# This motivated a competing-parent division model rather than another add-only heuristic.

# %%
display(Image(filename=str(ROOT/'assets/exact_error_budget_0.png')))
print('Source: completed AWS Notebook 28; exact attribution against the pinned evaluator.')
# Out:
# Source: completed AWS Notebook 28; exact attribution against the pinned evaluator.

# %% [markdown]
# ## 3 · Count distinct evidence, not just generated proposals
#
# The competing-parent model trained across embryos but had only a few distinct positive division events. It added 108 forks while leaving the scored metrics unchanged. The model was rejected rather than declared successful because its program completed.

# %%
display(Image(filename=str(ROOT/'assets/competing_parent_events_1.png')))
print('Source: completed AWS Notebook 29; unchanged metric, not an improvement.')
# Out:
# Source: completed AWS Notebook 29; unchanged metric, not an improvement.

# %% [markdown]
# ## 4 · Latest work and reproducibility boundary
#
# The image-appearance continuation experiment adds local 3D image descriptors to geometric matching. Its latest attempt stopped at the first frame with **IMAGE_COORDINATE_BOUNDS**, before any project-data fit. Notebook 30 is therefore not represented as completed.
#
# The next scientific step is a coordinate-convention diagnosis and first-frame regression, not a silent clipping workaround. Meanwhile, this publication preserves useful completed evidence and the actual latest source.
#
# AWS retains licensed data, weights, caches, and original working files. GitHub receives code, selected tests, notices, executed notebooks, and compact receipts. CI checks these public artifacts without pretending to rerun the full private pipeline.

# %%
latest=summary['latest_attempt']
assert latest['new_fits']==0 and not latest['notebook30_completed']
print(json.dumps(latest,indent=2))
print('PORTFOLIO_EVIDENCE_OVERVIEW_COMPLETE')
# Out:
# {
#   "name": "image-appearance continuation association",
#   "status": "blocked_before_fit",
#   "error": "IMAGE_COORDINATE_BOUNDS",
#   "elapsed_seconds": 31.319,
#   "new_fits": 0,
#   "new_submissions": 0,
#   "notebook30_completed": false
# }
# PORTFOLIO_EVIDENCE_OVERVIEW_COMPLETE

# %% [markdown]
# ## Continue reading
#
# [Notebook guide](README.md) · [Model card](../docs/MODEL_CARD.md) · [Experiment ledger](../docs/EXPERIMENTS.md) · [Reproduction matrix](../docs/REPRODUCTION_MATRIX.md) · [Attribution](../THIRD_PARTY_NOTICES.md)
